# %%
#Plotting dxy here to check the status

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys
import hist
import hist.intervals


sys.path.append("/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/analysisTools")
import plotTools as ptools
import utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# f_sig = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/coffea/AllInOne_2022/Sept1_inpTbins.coffea"

f_sig = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/coffea/BigSamples_2022/Sep2_Resolution.coffea"

sig_histo = util.load(f_sig) [0]
# sig_histo

# %%
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable':'DXY',
    'cut': 'cut1',
    'year': 2022
}
style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': None,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': "dxy (in cm)",
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': "Gen",    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': './plots/signal_2018',
    'outName': f'gen_ele_vxy10_m110.png'
}
#signal points

samples = {
    # 10: 
    # {
        
    #     0.2: [100],
        
    # },
    
    # 20: 
    # {
        
    #     0.2: [100],
        
    # },
    # 30: 
    # {
       
    #     0.2: [100]
    # },
    # 40: 
    # {
    #     0.2: [100],
    # },
    # 50:
    # {
        
    #     0.2: [100],
    # },
    # 60:
    # {
        
    #      0.1: [100],
    #      0.2: [100]
    
    # },
    # 70:
    # {    0.1: [100],
    #      0.2: [100],
    # },
    # 80:
    # {    0.1: [100],
    #      0.2: [100],
    # },
    # 90:
    # {    0.1: [100],
    #      0.2: [100],
    # },
    100:
    {    0.1: [100],
         # 0.2: [100],
    }
 
}
h_list_lpt=[]
h_sum_lpt = None

for m1,deltas in samples.items():
    for delta, ctaus in deltas.items():
        for ctau in ctaus:
            h_lpt = ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
#                                           mchi  dmchi   ctau     m1     m2  \
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100  105.0   10.0  100.0  100.0  110.0
#
#                                          delta  \
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100    0.1
#
#                                                                             name
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100  sig_2022_Mchi-105p0_dMchi-10p0_ctau-100

# %%
fig, ax = plt.subplots(figsize=(7,7))

plot_dict = {
    'variable':'dxy_gen',
    'cut': 'cut1',
    'year': 2022
}
style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': None,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': "dxy (in cm)",
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': "Gen",    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': './plots/signal_2018',
    'outName': f'gen_ele_vxy10_m110.png'
}
#signal points

samples = {
    # 10: 
    # {
        
    #     0.2: [100],
        
    # },
    
    # 20: 
    # {
        
    #     0.2: [100],
        
    # },
    # 30: 
    # {
       
    #     0.2: [100]
    # },
    # 40: 
    # {
    #     0.2: [100],
    # },
    # 50:
    # {
        
    #     0.2: [100],
    # },
    # 60:
    # {
        
    #      0.1: [100],
    #      0.2: [100]
    
    # },
    # 70:
    # {    0.1: [100],
    #      0.2: [100],
    # },
    # 80:
    # {    0.1: [100],
    #      0.2: [100],
    # },
    # 90:
    # {    0.1: [100],
    #      0.2: [100],
    # },
    100:
    {    0.1: [100],
         # 0.2: [100],
    }
 
}
h_list_lpt=[]
h_sum_lpt = None

for m1,deltas in samples.items():
    for delta, ctaus in deltas.items():
        for ctau in ctaus:
            h_lpt = ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
            



plot_dict = {
    'variable':'Lpt_dxy_flat',
    'cut': 'cut1',
    'year': 2022
}
style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': None,
    'xlim': [-3,3],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': "dxy (in cm)",
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': "GED",    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': './plots/signal_2018',
    'outName': f'gen_ele_vxy10_m110.png'
}

samples = {

    100:
    {    0.1: [100],
         # 0.2: [100],
    }
}
 

h_list_lpt=[]
h_sum_lpt = None

for m1,deltas in samples.items():
    for delta, ctaus in deltas.items():
        for ctau in ctaus:
            h_lpt = ptools.plot_signal_1D(sig_histo, m1, delta, ctau, plot_dict, style_dict)
# Out:
#                                           mchi  dmchi   ctau     m1     m2  \
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100  105.0   10.0  100.0  100.0  110.0
#
#                                          delta  \
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100    0.1
#
#                                                                             name
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100  sig_2022_Mchi-105p0_dMchi-10p0_ctau-100
#                                           mchi  dmchi   ctau     m1     m2  \
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100  105.0   10.0  100.0  100.0  110.0
#
#                                          delta  \
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100    0.1
#
#                                                                             name
# sig_2022_Mchi-105p0_dMchi-10p0_ctau-100  sig_2022_Mchi-105p0_dMchi-10p0_ctau-100
