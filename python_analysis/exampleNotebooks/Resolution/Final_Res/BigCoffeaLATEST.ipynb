# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/analysisTools/")
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os
from analysisTools import loadSchema
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

# %%
sample_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/configs/sample_configs/signal_2022_Mchi_bigsample_ctau100_aEM.json"

cuts_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/cut_configs/cuts_DSCB.py" 

histos_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/histo_configs/Lxy_res_histo_for_fig20_pT.py"  
# model_config = "../configs/models/BDT_NJetG0_allSigns_goodvtx_v11_max_depth_7_n_estimators_800_lr_0.005.json"

# %%
outdir = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/coffea/BigSamples_2022/"

os.makedirs(outdir, exist_ok=True)

# %%
# analyzer = Analyzer(sample_config, histos_config, cuts_config) 
# analyzer = Analyzer(sample_config, histos_config, cuts_config, max_samples=-1) 

analyzer = Analyzer(sample_config, histos_config, cuts_config, max_samples=1,max_files_per_samp=1) 

t1 = time.time()
print ("t1=", t1)
out = analyzer.process(execr="iterative")
t2 = time.time()
print ("t2=", t2)


util.save(out,f"{outdir}/Beam_Big_Coffea_Resolution.coffea")
