# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/analysisTools/")
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os
from analysisTools import loadSchema
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

print("has singletons?", hasattr(ak, "singletons"))
print("awkward module path:", getattr(ak, "__file__", "<built-in>"))
print(ak.__version__)
# Out:
# has singletons? True
# awkward module path: /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/__init__.py
# 1.10.3

# %%
# sample_config = "../configs/sample_configs/signal_2022_Mchi-77p0_dMchi-14p0_ctau-1_100_aEM.json"
# sample_config = "../configs/sample_configs/signal_2022_Mchi-22p0_dMchi-4p0_ctau-1_100_aEM.json"
# sample_config = "../configs/sample_configs/signal_2022_Mchi-44p0_dMchi-8p0_ctau-1_100_aEM.json"


# sample_config = "../configs/sample_configs/signal_2022_Mchi_10_30_50_ctau10mm_AllInOne_aEM.json"
sample_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/configs/sample_configs/signal_2022_Run3_sigfiles_2022_aEM.json"

cuts_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/cut_configs/cuts.py" 

histos_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/histo_configs/SimpleResoltuionPlot_Lxybin.py"  
# model_config = "../configs/models/BDT_NJetG0_allSigns_goodvtx_v11_max_depth_7_n_estimators_800_lr_0.005.json"

# %%
outdir = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/coffea/AllInOne_2022/"
# outdir = "../coffea/SampleFactoryProducts_2022/"

os.makedirs(outdir, exist_ok=True)

# %%
analyzer = Analyzer(sample_config, histos_config, cuts_config,max_files_per_samp=1) 

t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

util.save(out,f"{outdir}/Resolution_new_lxy.coffea")
# util.save(out,f"{outdir}/Sig77_14_ctau1_100.coffea")

# util.save(out,f"{outdir}/Sig77_14_ctau1_100.coffea")
# Out:
# Running with systematics:  None
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# All good!
# Good!
# GenEle_pt= [13.8, 5.36, 6.24, 10.4, 21.3, 9.1, 9.84, ... 7.29, 22.7, 28.7, 7.53, 11.9, 6.07]
# 340
# GenPos_pt= [8.16, 8.53, 8.88, 8.13, 18.8, 3.76, 12.1, ... 32, 5.44, 13.4, 17.6, 7.68, 16.1, 16]
# 340
# Gen_pt= [[13.8, 8.16], [5.36, 8.53], [6.24, 8.88], ... 7.53, 7.68], [11.9, 16.1], [6.07, 16]]
# len(Gen_pt_FLAT)= 680
# Lpt_pt= [[13.8, 7.45], [8.47, 5.3], [7.86, 6.19, ... 7.51, 6.22], [16.4, 11.8], [15.8, 6.11]]
# len(Lpt_pt_flat)= 680
# GED_pt= [[13.7, 7.57], [8.51, 5.32], [7.95, 6.2], ... [8.11, 6.27], [16.4, 11.8], [16, 6.12]]
# len(GED_pt_flat)= 680
# Res_GED= [-0.0031, -0.0719, 0.588, -0.376, 0.274, ... -0.184, 0.38, -0.266, 1.63, -0.618]
# Res_LPT= [0.000487, -0.087, 0.581, -0.378, 0.26, ... -0.19, 0.377, -0.266, 1.6, -0.619]
# All good!
# Good!
# GenEle_pt= [2.75, 17.9, 14, 21.9, 35.7, 9.08, 20.3, ... 14.3, 28, 35.7, 37.2, 26.5, 27.2, 23.2]
# 19
# GenPos_pt= [29.6, 22.5, 26.5, 9.08, 39.9, 27.1, 44.1, ... 32.3, 19.5, 19.6, 41.2, 6.99, 58.7]
# 19
# Gen_pt= [[2.75, 29.6], [17.9, 22.5], [14, 26.5], ... 26.5, 41.2], [27.2, 6.99], [23.2, 58.7]]
# len(Gen_pt_FLAT)= 38
# Lpt_pt= [[28.6, 2.71], [22.7, 17.9], [25.6, 14.2], ... 32.6, 27], [27.8, 7.02], [47.8, 21.6]]
# len(Lpt_pt_flat)= 38
# GED_pt= [[29.1, 2.71], [22.9, 18], [28.3, 14.2], ... [41.3, 27.4], [28, 6.96], [58.2, 24]]
# len(GED_pt_flat)= 38
# Res_GED= [9.59, -0.908, 0.276, -0.201, 1.03, -0.466, ... -0.333, 0.029, -0.00472, 1.5, -0.591]
# Res_LPT= [9.41, -0.908, 0.264, -0.206, 0.828, ... -0.344, 0.0206, 0.0039, 1.06, -0.632]
# All good!
# Good!
# GenEle_pt= [10, 3.18, 7.46, 10.9, 28.1, 18.6, 9.13, ... 30.5, 31.6, 14.8, 6.89, 11.2, 6.78]
# 39
# GenPos_pt= [8.95, 24.9, 22.9, 15.6, 8.24, 14.4, 4.26, ... 31.1, 10.4, 14.4, 25.2, 7.23, 21.7]
# 39
# Gen_pt= [[10, 8.95], [3.18, 24.9], [7.46, 22.9], ... 6.89, 25.2], [11.2, 7.23], [6.78, 21.7]]
# len(Gen_pt_FLAT)= 78
# Lpt_pt= [[10.3, 8.38], [24.6, 2.71], [20.5, 7.57, ... 6.58], [9.18, 6.95], [20.7, 6.48]]
# len(Lpt_pt_flat)= 78
# GED_pt= [[8.51, 5.91], [25.1, 2.71], [20.4, 7.71, ... 0.743], [9.15, 6.92], [23.2, 6.48]]
# len(GED_pt_flat)= 78
# Res_GED= [-0.152, -0.339, 6.89, -0.891, 1.73, ... -0.97, -0.184, -0.0418, 2.42, -0.702]
# Res_LPT= [0.0295, -0.064, 6.74, -0.891, 1.75, ... -0.739, -0.182, -0.0379, 2.06, -0.702]
# All good!
# Good!
# GenEle_pt= [23.3, 37.8, 30.2, 14.1, 3.71, 26.2, 21.2, ... 30.9, 22.1, 18.1, 16.6, 7.04, 18.9]
# 29
# GenPos_pt= [20.1, 61.1, 27.3, 6.93, 53.1, 12.7, 4.25, ... 41.1, 25.2, 46.2, 36.9, 7.9, 25.5]
# 29
# Gen_pt= [[23.3, 20.1], [37.8, 61.1], [30.2, 27.3, ... 16.6, 36.9], [7.04, 7.9], [18.9, 25.5]]
# len(Gen_pt_FLAT)= 58
# Lpt_pt= [[23.5, 20.7], [50.5, 33.8], [24.5, 20.9], ... [38.1, 16], [7.96, 7], [24, 18.6]]
# len(Lpt_pt_flat)= 58
# GED_pt= [[22.5, 19.8], [60.1, 30.2], [30.4, 27.6], ... 38.4, 15.9], [8.07, 7.17], [25, 18.8]]
# len(GED_pt_flat)= 58
# Res_GED= [-0.0346, -0.016, 0.591, -0.505, 0.00363, ... -0.568, 0.146, -0.0921, 0.326, -0.263]
# Res_LPT= [0.00507, 0.0303, 0.335, -0.447, -0.19, ... -0.567, 0.13, -0.114, 0.271, -0.27]
# All good!
# Good!
# GenEle_pt= [14.9, 20.5, 7.66, 19, 4.27, 20.7, 25.7, ... 6.1, 13.7, 14.8, 11.7, 11.9, 13.5, 11.8]
# 294
# GenPos_pt= [3.79, 9.76, 7.57, 8.16, 9.22, 21.4, 3.55, ... 5.8, 11.6, 6.05, 9.11, 7.66, 12.3]
# 294
# Gen_pt= [[14.9, 3.79], [20.5, 9.76], [7.66, 7.57, ... 9.11], [13.5, 7.66], [11.8, 12.3]]
# len(Gen_pt_FLAT)= 588
# Lpt_pt= [[14.8, 3.83], [18.9, 5.35], [7.78, 7.57, ... 8.62], [13.1, 7.04], [13.3, 11.3]]
# len(Lpt_pt_flat)= 588
# GED_pt= [[15.1, 3.84], [20.3, 5.56], [7.77, 7.68], ... 11.2, 8.68], [13.2, 7.06], [12.4, 12]]
# len(GED_pt_flat)= 588
# Res_GED= [0.0114, 0.0132, -0.00997, -0.431, 0.0144, ... -0.022, -0.078, 0.0447, -0.0267]
# Res_LPT= [-0.0114, 0.0103, -0.0769, -0.453, 0.0152, ... -0.0258, -0.0814, 0.123, -0.0833]
# All good!
# Good!
# GenEle_pt= [6.36, 6.45, 3.54, 10.2, 11, 21.6, 15.1, ... 4.21, 5.23, 14.6, 8.22, 5.69, 20.8]
# 33
# GenPos_pt= [23.5, 11, 11.4, 6.11, 10.5, 24.1, 14.3, ... 12.1, 19.1, 7.1, 29.5, 3.55, 11.3, 8.47]
# 33
# Gen_pt= [[6.36, 23.5], [6.45, 11], [3.54, 11.4], ... 8.22, 3.55], [5.69, 11.3], [20.8, 8.47]]
# len(Gen_pt_FLAT)= 66
# Lpt_pt= [[20, 6.12], [9.99, 6.34], [11.6, 3.49], ... 3.23, 2.91], [11.8, 5.38], [19.9, 8.37]]
# len(Lpt_pt_flat)= 66
# GED_pt= [[22.8, 5.75], [10.4, 6.31], [11.5, 3.49, ... 3.26], [12.4, 5.35], [20.2, 8.18]]
# len(GED_pt_flat)= 66
# Res_GED= [2.58, -0.755, 0.619, -0.428, 2.24, ... -0.084, 1.17, -0.527, -0.0264, -0.0343]
# Res_LPT= [2.15, -0.739, 0.55, -0.425, 2.29, ... -0.181, 1.08, -0.525, -0.0433, -0.0111]
# All good!
# Good!
# GenEle_pt= [22, 7.88, 33.3, 44.9, 40.8, 13.5, 21.5, ... 14.6, 23.3, 22.7, 17.4, 33.9, 14.5]
# 37
# GenPos_pt= [12.6, 54.9, 21.2, 21.8, 31.4, 9.36, 18.6, ... 22, 19.4, 8, 29.3, 17.6, 5.41, 31.3]
# 37
# Gen_pt= [[22, 12.6], [7.88, 54.9], [33.3, 21.2], ... 17.4, 17.6], [33.9, 5.41], [14.5, 31.3]]
# len(Gen_pt_FLAT)= 74
# Lpt_pt= [[21.2, 12.2], [48.9, 7.25], [33.2, 20.8], ... [17.1, 8], [32.1, 4.56], [30.7, 14.3]]
# len(Lpt_pt_flat)= 74
# GED_pt= [[21.7, 12.1], [57, 7.21], [33.3, 21], ... [17.2, 12.9], [33.1, 4.81], [30.7, 14.3]]
# len(GED_pt_flat)= 74
# Res_GED= [-0.0149, -0.0437, 6.24, -0.869, 0.00145, ... -0.271, -0.0221, -0.112, 1.11, -0.542]
# Res_LPT= [-0.0364, -0.036, 5.21, -0.868, -0.0034, ... -0.546, -0.0533, -0.158, 1.11, -0.544]
# All good!
# Good!
# GenEle_pt= [6.01, 19.6, 16.5, 6.16, 7.54, 14.9, 13.4, ... 28.3, 6.79, 5.77, 6.99, 13.3, 11.8]
# 292
# GenPos_pt= [8.09, 25.1, 16, 2.48, 15, 38, 27, 7.08, ... 9.08, 7.61, 11.1, 5.08, 5.9, 13.2, 20]
# 292
# Gen_pt= [[6.01, 8.09], [19.6, 25.1], [16.5, 16], ... [6.99, 5.9], [13.3, 13.2], [11.8, 20]]
# len(Gen_pt_FLAT)= 584
# Lpt_pt= [[7.78, 6.05], [24, 19.3], [16.8, 15.9], ... 6.37, 6.08], [13.2, 11.6], [11.1, 7.95]]
# len(Lpt_pt_flat)= 584
# GED_pt= [[7.79, 6.06], [24.7, 19.4], [16.9, 15.8], ... 6.47, 6.08], [13.3, 12], [22.7, 8.55]]
# len(GED_pt_flat)= 584
# Res_GED= [0.296, -0.251, 0.264, -0.227, 0.0249, ... 0.0316, 0.00211, -0.0942, 0.926, -0.572]
# Res_LPT= [0.294, -0.253, 0.226, -0.228, 0.0215, ... 0.031, -0.00368, -0.125, -0.0553, -0.602]
# All good!
# Good!
# GenEle_pt= [18.7, 8.27, 21.4, 24.8, 3, 6.52, 46.6, ... 25.9, 41.1, 29, 14.5, 13.8, 19.9, 7.53]
# 43
# GenPos_pt= [7.21, 6.61, 4.16, 75.5, 26, 9, 33.3, ... 8.83, 14.1, 19, 14.4, 24.2, 14.9, 9.57]
# 43
# Gen_pt= [[18.7, 7.21], [8.27, 6.61], [21.4, 4.16, ... 24.2], [19.9, 14.9], [7.53, 9.57]]
# len(Gen_pt_FLAT)= 86
# Lpt_pt= [[18.8, 7.03], [8.51, 6.5], [21.7, 4.11, ... 20.8, 13.4], [19.1, 14.8], [7.89, 7.58]]
# len(Lpt_pt_flat)= 86
# GED_pt= [[18.9, 7.11], [8.41, 7.18], [22.1, 4.13, ... 14.6], [19.8, 14.8], [7.66, 7.54]]
# len(GED_pt_flat)= 86
# Res_GED= [0.0083, -0.0141, 0.017, 0.0857, 0.0337, ... -0.00532, -0.00614, 0.0172, -0.212]
# Res_LPT= [0.00341, -0.0245, 0.0293, -0.0176, 0.0167, ... -0.0377, -0.0121, 0.0477, -0.207]
# All good!
# Good!
# GenEle_pt= [7.4, 10.3, 13.4, 8.29, 4.33, 17.6, 8.91, ... 5.31, 3.11, 7.46, 6.71, 9.69, 11.3]
# 166
# GenPos_pt= [9.5, 10.5, 8.42, 7.31, 6.2, 10.3, 9.07, ... 18.2, 2.71, 8.16, 8.76, 7.3, 17.7, 6.95]
# 166
# Gen_pt= [[7.4, 9.5], [10.3, 10.5], [13.4, 8.42], ... [6.71, 7.3], [9.69, 17.7], [11.3, 6.95]]
# len(Gen_pt_FLAT)= 332
# Lpt_pt= [[9.72, 7.69], [8.79, 7.85], [13.1, 8.73, ... 6.48], [17.4, 9.87], [11.5, 7.02]]
# len(Lpt_pt_flat)= 332
# GED_pt= [[9.2, 7.59], [9.88, 8.84], [13.2, 8.81], ... 7.38, 6.59], [17.6, 9.9], [11.5, 6.96]]
# len(GED_pt_flat)= 332
# Res_GED= [0.244, -0.201, -0.0426, -0.155, -0.0148, ... 0.813, -0.442, 0.016, 0.000984]
# Res_LPT= [0.314, -0.19, -0.148, -0.25, -0.0229, ... -0.112, 0.798, -0.443, 0.0164, 0.0105]
# All good!
# Good!
# GenEle_pt= [8.06, 7.9, 3.58, 6.83, 14.2, 6.84, 6.51, ... 8.2, 5.21, 7.94, 2.56, 3.86, 6.53]
# 388
# GenPos_pt= [5.68, 7.41, 4.39, 6.77, 4.88, 13.7, 8.59, ... 19.2, 3.54, 6.67, 4.85, 7.58, 5.88]
# 388
# Gen_pt= [[8.06, 5.68], [7.9, 7.41], [3.58, 4.39, ... 2.56, 4.85], [3.86, 7.58], [6.53, 5.88]]
# len(Gen_pt_FLAT)= 776
# Lpt_pt= [[7.96, 5.89], [7.76, 7.38], [4.38, 3.56, ... 4.62, 2.6], [7.48, 2.83], [6.57, 4.35]]
# len(Lpt_pt_flat)= 776
# GED_pt= [[8.04, 5.8], [7.74, 7.38], [4.38, 3.5], ... [4.65, 2.6], [7.48, 2.83], [6.58, 5.73]]
# len(GED_pt_flat)= 776
# Res_GED= [-0.00281, 0.0213, -0.0193, -0.00468, 0.223, ... 0.937, -0.626, 0.00847, -0.0261]
# Res_LPT= [-0.0131, 0.0366, -0.0168, -0.00451, 0.223, ... 0.935, -0.627, 0.00629, -0.261]
# All good!
# Good!
# GenEle_pt= [8.59, 9.4, 5.21, 19.8, 7.77, 10.7, 9.72, ... 19.1, 20.6, 6.69, 5.18, 27.9, 2.81]
# 174
# GenPos_pt= [3.76, 7.03, 12, 13.2, 12.4, 43.3, 22.7, ... 6.57, 14.1, 4.02, 3.76, 11.6, 7.25]
# 174
# Gen_pt= [[8.59, 3.76], [9.4, 7.03], [5.21, 12], ... [5.18, 3.76], [27.9, 11.6], [2.81, 7.25]]
# len(Gen_pt_FLAT)= 348
# Lpt_pt= [[8.35, 3.18], [8.96, 7], [12.3, 4.95], ... [5.01, 3.75], [24.4, 12.3], [7.16, 2.83]]
# len(Lpt_pt_flat)= 348
# GED_pt= [[8.17, 3.21], [8.82, 7.02], [12.5, 5.03, ... 3.78], [27.9, 12.1], [7.24, 3.18]]
# len(GED_pt_flat)= 348
# Res_GED= [-0.0497, -0.146, -0.0616, -0.000586, 1.4, ... -0.00152, 0.0468, 1.58, -0.562]
# Res_LPT= [-0.0285, -0.155, -0.0472, -0.00452, 1.36, ... -0.00089, -0.126, 0.0585, 1.55, -0.61]
# All good!
# Good!
# GenEle_pt= [7.7, 4.2, 4.84, 7.87, 22.2, 11.1, 7.75, ... 6.14, 22.5, 9.2, 6.89, 13.6, 6.44, 20]
# 62
# GenPos_pt= [13, 8.07, 8.81, 20.3, 11.1, 17.6, 19.5, ... 7.91, 19, 11.1, 14.9, 32.3, 5.01, 7.65]
# 62
# Gen_pt= [[7.7, 13], [4.2, 8.07], [4.84, 8.81], ... [13.6, 32.3], [6.44, 5.01], [20, 7.65]]
# len(Gen_pt_FLAT)= 124
# Lpt_pt= [[12.8, 5.98], [7.87, 4.33], [8.78, 4.82], ... [26, 13.4], [5.44, 5.29], [18, 7.72]]
# len(Lpt_pt_flat)= 124
# GED_pt= [[12.9, 7.25], [7.89, 4.51], [8.83, 4.86], ... 24, 13.4], [5.63, 4.86], [18.9, 7.71]]
# len(GED_pt_flat)= 124
# Res_GED= [0.673, -0.441, 0.878, -0.442, 0.823, ... -0.584, -0.125, -0.0291, -0.0546, 0.00756]
# Res_LPT= [0.658, -0.539, 0.873, -0.463, 0.814, ... -0.584, -0.155, 0.0577, -0.0979, 0.00949]
# All good!
# Good!
# GenEle_pt= [21.7, 6.22, 16.4, 14.3, 6.81, 8.08, 7.41, ... 8.78, 4.24, 16.7, 24.8, 6.31, 9.14]
# 97
# GenPos_pt= [5.22, 8.26, 4.55, 9.97, 12.2, 7.86, 25.1, ... 6.02, 15.4, 5.56, 25.7, 8.25, 15.3]
# 97
# Gen_pt= [[21.7, 5.22], [6.22, 8.26], [16.4, 4.55, ... 25.7], [6.31, 8.25], [9.14, 15.3]]
# len(Gen_pt_FLAT)= 194
# Lpt_pt= [[23.4, 4.32], [8.22, 4.58], [16.4, 3.88], ... 26, 23.2], [7.79, 6.32], [14.6, 8.17]]
# len(Lpt_pt_flat)= 194
# GED_pt= [[21.7, 4.17], [8.19, 5.2], [16.8, 4.55, ... 25.7, 23.3], [7.81, 6.36], [14.7, 8.26]]
# len(GED_pt_flat)= 194
# Res_GED= [-0.00274, -0.201, 0.317, -0.37, 0.028, ... -0.095, 0.239, -0.229, 0.603, -0.46]
# Res_LPT= [0.078, -0.172, 0.322, -0.446, -0.000106, ... -0.0963, 0.235, -0.234, 0.602, -0.466]
# All good!
# Good!
# GenEle_pt= [6.78, 10.4, 5.22, 14.3, 3.45, 7.45, 14.7, ... 6.09, 8.67, 12.8, 6.2, 14.5, 5.1]
# 114
# GenPos_pt= [4.21, 13.4, 5.69, 9.59, 7.27, 9.57, 2.89, ... 6.71, 8.5, 7.59, 7.12, 20.9, 3.87]
# 114
# Gen_pt= [[6.78, 4.21], [10.4, 13.4], [5.22, 5.69], ... 6.2, 7.12], [14.5, 20.9], [5.1, 3.87]]
# len(Gen_pt_FLAT)= 228
# Lpt_pt= [[6.69, 3.66], [13.3, 10.4], [5.62, 5.08, ... 5.51], [20.6, 12.2], [4.96, 4.73]]
# len(Lpt_pt_flat)= 228
# GED_pt= [[6.83, 3.74], [13.2, 9.36], [5.62, 5.14], ... 6.08, 5.62], [20.7, 13.3], [5.1, 3.8]]
# len(GED_pt_flat)= 228
# Res_GED= [0.00851, -0.113, 0.268, -0.303, 0.076, ... -0.211, 0.426, -0.36, -0.000258, -0.0194]
# Res_LPT= [-0.013, -0.13, 0.272, -0.224, 0.0756, ... -0.226, 0.416, -0.417, -0.027, 0.222]
# All good!
# Good!
# GenEle_pt= [14.9, 6.17, 5.33, 4.44, 4.98, 4.31, 12.3, ... 3.16, 6.51, 5.34, 3.27, 10.8, 5.49]
# 203
# GenPos_pt= [4.13, 8.65, 7.37, 5.4, 5.42, 6.2, 5.75, ... 4.33, 9.08, 8.1, 7.51, 4.19, 5.65, 2.02]
# 203
# Gen_pt= [[14.9, 4.13], [6.17, 8.65], [5.33, 7.37, ... 4.19], [10.8, 5.65], [5.49, 2.02]]
# len(Gen_pt_FLAT)= 406
# Lpt_pt= [[15.4, 4.04], [8.87, 5.42], [5.37, 5.09], ... [4.2, 3.2], [10.7, 5.5], [5.47, 2.01]]
# len(Lpt_pt_flat)= 406
# GED_pt= [[15.7, 4.02], [8.44, 5.38], [6.29, 5.4], ... [4.18, 3.28], [10.9, 5.5], [5.3, 2.1]]
# len(GED_pt_flat)= 406
# Res_GED= [0.0597, -0.0257, 0.368, -0.378, 0.18, ... -0.217, 0.0103, -0.0257, -0.0355, 0.0415]
# Res_LPT= [0.0363, -0.0205, 0.438, -0.373, 0.00681, ... -0.00783, -0.0268, -0.00457, -0.00496]
# All good!
# Good!
# GenEle_pt= [8.55, 8.45, 14.5, 7.31, 5.88, 12.4, 8.32, ... 11.8, 13.8, 8.32, 8.53, 43.6, 8.77]
# 157
# GenPos_pt= [5.24, 3.92, 19.2, 12.2, 18, 4.4, 8.01, ... 5.4, 7.7, 32, 20.2, 2.94, 9.12, 8.23]
# 157
# Gen_pt= [[8.55, 5.24], [8.45, 3.92], [14.5, 19.2, ... 2.94], [43.6, 9.12], [8.77, 8.23]]
# len(Gen_pt_FLAT)= 314
# Lpt_pt= [[8.91, 5.21], [8.69, 4.01], [20.3, 10.8], ... [7.46, 2.95], [42, 7.61], [7.9, 3.29]]
# len(Lpt_pt_flat)= 314
# GED_pt= [[8.89, 5.25], [8.71, 4], [20, 11.9], ... [7.46, 3.31], [43.1, 7.63], [7.84, 3.05]]
# len(GED_pt_flat)= 314
# Res_GED= [0.0397, 0.000575, 0.03, 0.0211, 0.381, ... 0.127, -0.0125, -0.163, -0.107, -0.63]
# Res_LPT= [0.0415, -0.00682, 0.0285, 0.023, 0.407, ... 0.00181, -0.0357, -0.165, -0.1, -0.601]
# All good!
# Good!
# GenEle_pt= [7.89, 8.21, 24.5, 8.38, 4.82, 7.76, 3.81, ... 13.4, 4.8, 8.12, 5.68, 7.68, 10.7]
# 96
# GenPos_pt= [6.31, 11.8, 3.17, 4.85, 5.83, 2.53, 8.94, ... 8.47, 5.82, 7.62, 9.48, 7.87, 11.2]
# 96
# Gen_pt= [[7.89, 6.31], [8.21, 11.8], [24.5, 3.17, ... 9.48], [7.68, 7.87], [10.7, 11.2]]
# len(Gen_pt_FLAT)= 192
# Lpt_pt= [[8.03, 6.43], [11.8, 9], [24.5, 3.15], ... [8.86, 4.25], [8.03, 7.54], [11.5, 10.2]]
# len(Lpt_pt_flat)= 192
# GED_pt= [[8.02, 6.52], [11.8, 9.13], [23.5, 3.2], ... [8.84, 4.65], [8, 7.55], [11.2, 10.4]]
# len(GED_pt_flat)= 192
# Res_GED= [0.0169, 0.0346, 0.435, -0.227, -0.0381, ... -0.509, 0.042, -0.0408, 0.0487, -0.0758]
# Res_LPT= [0.0187, 0.0201, 0.436, -0.237, 0.00239, ... 0.0454, -0.0414, 0.0741, -0.0921]
# All good!
# Good!
# GenEle_pt= [6.14, 3.38, 2.71, 14.4, 7.85, 5.4, 3.14, ... 23, 7.76, 16.5, 7.68, 6.79, 11.8, 4.59]
# 161
# GenPos_pt= [10, 24.7, 8.84, 8.26, 12.7, 7.01, 7.3, ... 16.3, 11.9, 6.83, 5.59, 6.2, 19.4, 9.99]
# 161
# Gen_pt= [[6.14, 10], [3.38, 24.7], [2.71, 8.84], ... [6.79, 6.2], [11.8, 19.4], [4.59, 9.99]]
# len(Gen_pt_FLAT)= 322
# Lpt_pt= [[9.35, 6.37], [24.1, 3.54], [7.87, 2.76, ... 5.85], [18.3, 10.5], [10.2, 5.23]]
# len(Lpt_pt_flat)= 322
# GED_pt= [[10.1, 6.83], [24.2, 3.56], [7.62, 2.77, ... 5.91], [18.3, 10.6], [10.1, 4.77]]
# len(GED_pt_flat)= 322
# Res_GED= [0.654, -0.318, 6.15, -0.856, 1.81, -0.687, ... -0.0471, 0.553, -0.454, 1.2, -0.523]
# Res_LPT= [0.524, -0.363, 6.13, -0.857, 1.9, -0.687, ... -0.0563, 0.548, -0.46, 1.23, -0.477]
# All good!
# Good!
# GenEle_pt= [11.5, 9, 3.71, 3.11, 5.35, 16.8, 7.63, ... 4.25, 4.31, 4.63, 4.63, 5.59, 4.56, 5.39]
# 25
# GenPos_pt= [15.8, 2.57, 4.82, 2.12, 5.53, 3.84, 4.15, ... 10.9, 2.68, 10.7, 9.85, 3.68, 6.65]
# 25
# Gen_pt= [[11.5, 15.8], [9, 2.57], [3.71, 4.82], ... [5.59, 9.85], [4.56, 3.68], [5.39, 6.65]]
# len(Gen_pt_FLAT)= 50
# Lpt_pt= [[16.1, 8.56], [8.97, 2.63], [4.68, 3.67, ... 9.93, 5.7], [3.56, 3.11], [6.63, 5.39]]
# len(Lpt_pt_flat)= 50
# GED_pt= [[16.4, 8.03], [9.11, 2.65], [4.7, 3.68], ... [6.73, 5.62], [3.5, 3], [6.46, 5.64]]
# len(GED_pt_flat)= 50
# Res_GED= [0.424, -0.492, 0.0125, 0.029, 0.266, ... -0.43, -0.232, -0.183, 0.199, -0.152]
# Res_LPT= [0.397, -0.459, -0.00358, 0.0204, 0.26, ... -0.422, -0.219, -0.154, 0.23, -0.19]
# All good!
# Good!
# GenEle_pt= [5.53, 3.51, 3.18, 3.33, 7.09, 4.19, 3.91, ... 7.45, 2.97, 2.1, 6.23, 3.13, 3.23]
# 20
# GenPos_pt= [2.17, 10.9, 2.46, 3.07, 5.9, 2.86, 6.27, ... 9.9, 3.27, 5.52, 4.99, 3.11, 2.06]
# 20
# Gen_pt= [[5.53, 2.17], [3.51, 10.9], [3.18, 2.46, ... 4.99], [3.13, 3.11], [3.23, 2.06]]
# len(Gen_pt_FLAT)= 40
# Lpt_pt= [[4.54, 2.14], [11.1, 3.57], [3.17, 2.45, ... 4.13], [2.87, 2.38], [3.19, 2.12]]
# len(Lpt_pt_flat)= 40
# GED_pt= [[5.02, 2.44], [11.1, 3.26], [3.17, 2.5], ... [6.31, 4.14], [2.88, 2.5], [3.23, 2.1]]
# len(GED_pt_flat)= 40
# Res_GED= [-0.0926, 0.125, 2.16, -0.703, -0.00291, ... -0.17, -0.0805, -0.196, 0.00163, 0.0215]
# Res_LPT= [-0.18, -0.0129, 2.15, -0.674, -0.00495, ... -0.171, -0.0835, -0.233, -0.0112, 0.028]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
