# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/analysisTools/")
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os
from analysisTools import loadSchema
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

print("has singletons?", hasattr(ak, "singletons"))
print("awkward module path:", getattr(ak, "__file__", "<built-in>"))
print(ak.__version__)
# Out:
# has singletons? True
# awkward module path: /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/__init__.py
# 1.10.3

# %%
sample_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/configs/sample_configs/Signal_2022_IMP_Run3_Sigfiles_resolution_aEM.json"

cuts_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/cut_configs/cuts_DSCB.py" 

histos_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/histo_configs/histo_for_fig20-Lxy.py"  
# model_config = "../configs/models/BDT_NJetG0_allSigns_goodvtx_v11_max_depth_7_n_estimators_800_lr_0.005.json"

# %%
outdir = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/coffea/AllInOne_2022/"
# outdir = "../coffea/SampleFactoryProducts_2022/"

os.makedirs(outdir, exist_ok=True)

# %%
analyzer = Analyzer(sample_config, histos_config, cuts_config, max_files_per_samp=1) 
# analyzer = Analyzer(sample_config, histos_config, cuts_config,max_samples=3, max_files_per_samp=1) 


t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

util.save(out,f"{outdir}/Resolution_DSCBsigma_LXY_withmanysamples.coffea")
# util.save(out,f"{outdir}/Sig77_14_ctau1_100.coffea")

# util.save(out,f"{outdir}/Sig77_14_ctau1_100.coffea")
# Out:
# Running with systematics:  None
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# All good!
# Good!
# Lpt_pt= [[10.4, 8.89], [10, 5.88], [19.4, 16.7], ... 16.4, 13.5], [22.7, 16.2], [11.7, 8.44]]
# len(Lpt_pt_flat)= 4932
# GED_pt= [[10.5, 8.54], [10.3, 5.9], [21.9, 16.9], ... [16.7, 13.5], [21.9, 16.3], [12, 8.48]]
# len(GED_pt_flat)= 4932
# Res_GED= [0.00249, -0.00875, 0.748, -0.443, 0.27, ... 0.06, -0.0285, -0.0155, 0.0423, -0.0219]
# Res_LPT= [-0.00485, 0.0314, 0.694, -0.445, 0.128, ... 0.00981, -0.0211, 0.0133, -0.0268]
# All good!
# Good!
# Lpt_pt= [[14.9, 14.4], [24, 3.79], [21.5, 9.41], ... 8.21, 3.62], [15.2, 5.74], [32.2, 18.5]]
# len(Lpt_pt_flat)= 24152
# GED_pt= [[19.5, 13.5], [29.6, 3.81], [21.9, 10.3, ... 2.36], [15.1, 5.75], [33.9, 20.8]]
# len(GED_pt_flat)= 24152
# Res_GED= [0.472, -0.345, -0.0674, -0.00516, 0.0215, ... -0.0279, -0.0131, 0.52, -0.383]
# Res_LPT= [0.127, -0.303, -0.244, -0.0109, 0.00312, ... -0.0259, -0.015, 0.444, -0.449]
# All good!
# Good!
# Lpt_pt= [[12.3, 5.98], [6.77, 5.02], [19, 8.46], ... [17.1, 11.3], [20.6, 17.2], [38, 11.8]]
# len(Lpt_pt_flat)= 42860
# GED_pt= [[12.3, 5.74], [7.91, 5.69], [27, 8.18], ... 17.4, 11.9], [22.3, 17.6], [37.8, 6.73]]
# len(GED_pt_flat)= 42860
# Res_GED= [1.09, -0.532, 0.401, -0.0671, 2.43, ... -0.325, 0.274, -0.286, -0.0752, 0.149]
# Res_LPT= [1.09, -0.513, 0.199, -0.177, 1.42, -0.677, ... -0.358, 0.179, -0.302, -0.07, 1.02]
# All good!
# Good!
# Lpt_pt= [[5.62, 3.15], [5.8, 5.51], [16.5, 5.29, ... 9.82, 7.37], [6.36, 4.83], [7.14, 2.99]]
# len(Lpt_pt_flat)= 12162
# GED_pt= [[5.63, 3.15], [5.9, 5.51], [16.3, 5.26, ... 9.94, 7.36], [6.53, 4.81], [7.15, 3.01]]
# len(GED_pt_flat)= 12162
# Res_GED= [0.0206, -0.0275, -0.0127, -0.00434, 2.01, ... -0.0116, 0.144, -0.284, 1.44, -0.629]
# Res_LPT= [0.0187, -0.0284, -0.0294, -0.00498, 2.03, ... -0.00997, 0.114, -0.28, 1.44, -0.632]
# All good!
# Good!
# Lpt_pt= [[7.55, 5.23], [6.88, 3.87], [13, 3.35], ... 11.2, 7.77], [6.93, 5.66], [8.75, 6.92]]
# len(Lpt_pt_flat)= 2504
# GED_pt= [[7.54, 5.24], [6.4, 3.88], [13.3, 3.33], ... 11.4, 7.8], [7.84, 5.71], [8.87, 7.04]]
# len(GED_pt_flat)= 2504
# Res_GED= [0.418, -0.293, 0.626, -0.472, 2.99, ... -0.356, 0.333, -0.274, -0.0334, 0.0354]
# Res_LPT= [0.42, -0.295, 0.747, -0.473, 2.9, -0.75, ... -0.358, 0.179, -0.28, -0.0455, 0.0176]
# All good!
# Good!
# Lpt_pt= [[11.4, 5.83], [15.4, 9.44], [6.41, 6.05, ... 7.43], [8.67, 2.38], [14.5, 7.98]]
# len(Lpt_pt_flat)= 20420
# GED_pt= [[11.6, 5.81], [16, 9.5], [6.37, 4.42], ... [13.3, 7.58], [8.86, 2.41], [14.7, 8.23]]
# len(GED_pt_flat)= 20420
# Res_GED= [0.991, -0.523, -0.0719, -0.0028, -0.0361, ... 0.0537, 2.69, -0.751, 0.00248, 0.0203]
# Res_LPT= [0.955, -0.521, -0.107, -0.00879, -0.031, ... 0.0318, 2.61, -0.754, -0.016, -0.0109]
# All good!
# Good!
# Lpt_pt= [[33.1, 7.53], [13.6, 3.87], [19.4, 12], ... [9.08, 5.78], [10.1, 4], [14.1, 8.02]]
# len(Lpt_pt_flat)= 22390
# GED_pt= [[32.1, 7.52], [14.1, 3.85], [20, 12], ... [9.26, 5.75], [10.2, 4.19], [15.3, 8.3]]
# len(GED_pt_flat)= 22390
# Res_GED= [-0.0255, -0.0418, 2.67, -0.746, -0.138, ... -0.489, -0.122, 0.0314, -0.0653, 0.0317]
# Res_LPT= [0.0024, -0.0396, 2.52, -0.744, -0.162, ... -0.137, -0.0171, -0.137, -0.00309]
# All good!
# Good!
# Lpt_pt= [[20.4, 15.7], [9.23, 6.09], [27.2, 21.9], ... [23, 14.9], [3.9, 3.89], [17, 10.2]]
# len(Lpt_pt_flat)= 4842
# GED_pt= [[20.6, 15.7], [9.38, 6.08], [28.4, 23.2], ... 23.5, 15.1], [3.91, 3.91], [17, 10.2]]
# len(GED_pt_flat)= 4842
# Res_GED= [0.293, -0.245, 0.0147, 0.0359, 0.0104, ... -0.34, 0.0572, -0.00768, 0.716, -0.402]
# Res_LPT= [0.279, -0.247, -0.00218, 0.0374, -0.0303, ... 0.0543, -0.0119, 0.717, -0.402]
# All good!
# Good!
# Lpt_pt= [[6.26, 4.4], [13.4, 6.02], [12.4, 9.29, ... 16.9, 2.69], [5.45, 3.37], [16.2, 5.84]]
# len(Lpt_pt_flat)= 39370
# GED_pt= [[6.4, 4.46], [13.4, 6.02], [13.1, 11.3], ... [16.6, 2.79], [6.22, 3.35], [16, 5.91]]
# len(GED_pt_flat)= 39370
# Res_GED= [-0.0491, 0.0139, 0.00309, 0.0111, -0.0242, ... -0.14, 0.00653, 0.0154, 0.0262]
# Res_LPT= [-0.0698, 0.000448, 0.00414, 0.0107, -0.0701, ... -0.247, 0.0117, 0.0277, 0.0147]
# All good!
# Good!
# Lpt_pt= [[8.15, 8.05], [13.1, 5.89], [29.1, 18.6, ... 2.56], [12.1, 9.93], [9.85, 8.07]]
# len(Lpt_pt_flat)= 18124
# GED_pt= [[8.09, 8.02], [13.3, 5.8], [29.2, 18.2, ... 4.95, 2.47], [12.1, 9.92], [9.79, 4.92]]
# len(GED_pt_flat)= 18124
# Res_GED= [0.0598, -0.0125, 1.15, -0.603, 0.524, ... -0.506, 0.00246, 0.0205, 0.114, 0.0846]
# Res_LPT= [0.067, -0.00943, 1.11, -0.597, 0.516, ... -0.488, 0.00105, 0.021, 0.12, 0.779]
# All good!
# Good!
# Lpt_pt= [[5.48, 3.55], [7.68, 2.02], [9.02, 7.34], ... [7.98, 7.22], [15.1, 4], [8.45, 6.44]]
# len(Lpt_pt_flat)= 2076
# GED_pt= [[5.54, 3.58], [7.59, 2.03], [8.91, 7.33], ... [8.05, 7.25], [15.5, 4], [8.64, 6.03]]
# len(GED_pt_flat)= 2076
# Res_GED= [0.556, -0.425, 0.00608, 0.0124, 0.211, ... 0.023, 0.034, -0.0151, 0.11, -0.214]
# Res_LPT= [0.54, -0.431, 0.0191, 0.00814, 0.226, ... 0.0186, 0.00668, -0.016, 0.0853, -0.161]
# All good!
# Good!
# Lpt_pt= [[10.9, 7.23], [4.65, 3.83], [15.5, 4.99, ... 6.71], [5.56, 4.66], [6.11, 3.76]]
# len(Lpt_pt_flat)= 10542
# GED_pt= [[12, 7.96], [4.62, 3.86], [15.9, 5.28], ... [10.8, 6.9], [5.17, 4.82], [6.14, 3.76]]
# len(GED_pt_flat)= 10542
# Res_GED= [0.358, -0.176, 0.0232, -0.00976, 0.0155, ... 0.00562, -0.117, 0.0524, -0.00353]
# Res_LPT= [0.235, -0.252, 0.0304, -0.0159, -0.0129, ... 0.0801, -0.146, 0.047, -0.00278]
# All good!
# Good!
# Lpt_pt= [[9.15, 6.24], [18.8, 2.46], [24.3, 10.6, ... 6.11], [27.3, 4.03], [7.84, 6.59]]
# len(Lpt_pt_flat)= 3366
# GED_pt= [[9.31, 6.3], [19, 2.46], [23.6, 10.6], ... [16, 6.12], [32.9, 4.08], [7.83, 6.57]]
# len(GED_pt_flat)= 3366
# Res_GED= [0.545, -0.315, -0.000676, 0.00209, -0.0532, ... -0.618, 6.29, -0.879, 0.211, -0.159]
# Res_LPT= [0.518, -0.321, -0.00949, 0.003, -0.0237, ... -0.619, 5.04, -0.88, 0.213, -0.156]
# All good!
# Good!
# Lpt_pt= [[22.6, 6.12], [9.41, 5.86], [13.3, 12.7, ... 18.8, 6.8], [8.22, 4.77], [16.3, 15.8]]
# len(Lpt_pt_flat)= 25718
# GED_pt= [[23.1, 6.12], [9.31, 5.85], [13.4, 12.2], ... [19.5, 5.64], [8.2, 4.78], [16, 15.9]]
# len(GED_pt_flat)= 25718
# Res_GED= [-0.0123, 0.0013, -0.00134, -0.0395, 0.0993, ... 0.0138, 0.00913, -0.0868, -0.00617]
# Res_LPT= [-0.0344, 0.00131, 0.0101, -0.0376, 0.0902, ... 0.0156, 0.00683, -0.0708, -0.0113]
# All good!
# Good!
# Lpt_pt= [[23.2, 19.8], [9.78, 5.28], [10.3, 8.38], ... 22.6, 11.6], [17.1, 3.25], [18, 15.7]]
# len(Lpt_pt_flat)= 364
# GED_pt= [[22.9, 20], [9.76, 5.31], [8.51, 5.91], ... [25.1, 11.7], [17, 3.3], [18.5, 16.4]]
# len(GED_pt_flat)= 364
# Res_GED= [0.129, -0.119, 0.0149, 0.0116, -0.152, ... -0.522, 4.22, -0.8, -0.123, 0.0316]
# Res_LPT= [0.144, -0.128, 0.0176, 0.00617, 0.0295, ... -0.525, 4.24, -0.804, -0.145, -0.0112]
# All good!
# Good!
# Lpt_pt= [[9.2, 5.36], [9.57, 8.1], [10.4, 9.65], ... 5.75, 4.87], [7.91, 2.41], [19.2, 12.3]]
# len(Lpt_pt_flat)= 8898
# GED_pt= [[8.43, 5.4], [9.6, 8.09], [10.3, 9.83], ... 5.76, 4.88], [7.82, 2.45], [18.8, 12.4]]
# len(GED_pt_flat)= 8898
# Res_GED= [0.43, -0.463, 0.109, -0.146, -0.0598, ... -0.138, 2.58, -0.681, -0.0149, 0.0731]
# Res_LPT= [0.559, -0.467, 0.106, -0.146, -0.0535, ... -0.141, 2.63, -0.686, 0.00302, 0.0654]
# All good!
# Good!
# Lpt_pt= [[18.7, 7.81], [9.56, 6.02], [6.07, 4.57, ... 4.97, 4.34], [5.8, 2.41], [6.28, 4.23]]
# len(Lpt_pt_flat)= 15262
# GED_pt= [[19.1, 7.78], [9.61, 5.98], [6.11, 4.54, ... 4.33], [5.83, 2.49], [5.59, 4.25]]
# len(GED_pt_flat)= 15262
# Res_GED= [0.000224, -0.00862, 0.582, -0.378, 0.00182, ... 0.985, -0.651, 0.319, -0.343]
# Res_LPT= [-0.0206, -0.00604, 0.574, -0.374, -0.00509, ... 0.978, -0.662, 0.482, -0.346]
# All good!
# Good!
# Lpt_pt= [[6.26, 4.4], [13.4, 6.02], [12.4, 9.29, ... 5.45, 3.37], [16.9, 2.69], [16.2, 5.84]]
# len(Lpt_pt_flat)= 39370
# GED_pt= [[6.4, 4.46], [13.4, 6.02], [13.1, 11.3], ... [6.22, 3.35], [16.6, 2.79], [16, 5.91]]
# len(GED_pt_flat)= 39370
# Res_GED= [-0.0491, 0.0139, 0.00309, 0.0111, -0.0242, ... 4.99, -0.852, 0.0154, 0.0262]
# Res_LPT= [-0.0698, 0.000448, 0.00414, 0.0107, -0.0701, ... 5.09, -0.857, 0.0277, 0.0147]
# All good!
# Good!
# Lpt_pt= [[7.11, 2.5], [28.6, 4.97], [21, 9.01], ... [10.4, 8.33], [12.7, 2.73], [9.82, 5.7]]
# len(Lpt_pt_flat)= 23870
# GED_pt= [[8.71, 2.62], [28.9, 5.02], [21, 9.1], ... [10.7, 8.38], [12.6, 2.71], [9.66, 5.75]]
# len(GED_pt_flat)= 23870
# Res_GED= [-0.111, 0.0237, 4.77, -0.827, 0.0479, ... -0.193, 0.0181, -0.0686, -0.0501, 0.0162]
# Res_LPT= [-0.275, -0.0239, 4.71, -0.828, 0.0483, ... -0.197, 0.022, -0.0597, -0.0338, 0.00805]
# All good!
# Good!
# Lpt_pt= [[6.08, 5.61], [14.8, 3.83], [7.33, 6.26, ... 7.43], [11.6, 6.01], [13.3, 8.85]]
# len(Lpt_pt_flat)= 2664
# GED_pt= [[6.09, 5.79], [15.1, 3.84], [6.52, 6.26, ... 7.43], [11.2, 6.03], [15.6, 8.75]]
# len(GED_pt_flat)= 2664
# Res_GED= [0.0705, -0.00706, 0.0114, 0.0132, 0.154, ... 0.0265, 0.0229, -0.0203, 0.82, -0.419]
# Res_LPT= [0.0699, -0.0374, -0.0114, 0.0103, 0.297, ... 0.027, 0.0569, -0.0231, 0.549, -0.412]
# All good!
# Good!
# Lpt_pt= [[17.2, 4.14], [7.27, 5.42], [20.6, 12.2], ... 10.5, 5.65], [14, 3.86], [6.45, 2.84]]
# len(Lpt_pt_flat)= 360
# GED_pt= [[17.2, 4.12], [7.29, 5.43], [22.7, 12.3, ... 5.62], [14.1, 3.83], [7.55, 2.81]]
# len(GED_pt_flat)= 360
# Res_GED= [3.09, -0.763, -0.00828, 0.00392, 0.0314, ... -0.0343, 0.0349, -0.218, -0.0107]
# Res_LPT= [3.09, -0.761, -0.0111, 0.00159, -0.0641, ... -0.0404, 0.0419, -0.332, -0.000862]
# All good!
# Good!
# Lpt_pt= [[5.6, 2.34], [10.9, 9.39], [5.04, 3.92], ... [4.47, 4.42], [5.73, 4.63], [10.4, 7]]
# len(Lpt_pt_flat)= 1384
# GED_pt= [[5.53, 2.44], [11, 9.55], [5.24, 4.15], ... [4.5, 4.46], [5.71, 4.75], [10.1, 7.04]]
# len(GED_pt_flat)= 1384
# Res_GED= [-0.0232, 0.055, 0.0604, 0.0751, 0.0361, ... 0.00255, -0.0198, -0.0827, 0.000559]
# Res_LPT= [-0.0108, 0.013, 0.0574, 0.0566, -0.00281, ... 0.00498, -0.0446, -0.0598, -0.00461]
# All good!
# Good!
# Lpt_pt= [[6.66, 3.68], [13.3, 10.3], [6.82, 3.13, ... 6.49], [6.31, 4.75], [8.85, 3.89]]
# len(Lpt_pt_flat)= 12282
# GED_pt= [[6.7, 3.66], [13.9, 10.2], [6.73, 3.13], ... 15.1, 2.68], [6.3, 4.84], [9.15, 3.84]]
# len(GED_pt_flat)= 12282
# Res_GED= [-0.00675, 0.0515, 0.314, -0.227, 1.05, ... -0.244, 0.237, -0.227, 0.0119, 0.0124]
# Res_LPT= [-0.0132, 0.0571, 0.261, -0.22, 1.08, ... 0.832, 0.239, -0.24, -0.0215, 0.0265]
# All good!
# Good!
# Lpt_pt= [[13.3, 9.14], [7.31, 3.73], [14.5, 7.49, ... 7.43], [6.47, 3.64], [22.3, 4.63]]
# len(Lpt_pt_flat)= 23980
# GED_pt= [[11.5, 7.87], [7.33, 3.72], [14.4, 7.53, ... 9.34, 7.42], [6.51, 3.7], [22.8, 4.86]]
# len(GED_pt_flat)= 23980
# Res_GED= [0.000124, -0.0424, -0.1, -0.0718, 0.963, ... -0.0333, -0.0375, -0.0272, 0.0432]
# Res_LPT= [0.163, 0.112, -0.103, -0.0695, 0.97, ... -0.0385, -0.0544, -0.0482, -0.00478]
# All good!
# Good!
# Lpt_pt= [[11.9, 6.77], [24, 4.95], [7.78, 6.05], ... 6.31, 5.95], [10.7, 7.98], [5.41, 3.59]]
# len(Lpt_pt_flat)= 2482
# GED_pt= [[12, 6.6], [26.8, 5.16], [7.79, 6.06], ... [6.24, 5.96], [10.8, 7.46], [5.46, 3.59]]
# len(GED_pt_flat)= 2482
# Res_GED= [-0.0648, -0.0108, -0.0179, 0.271, 0.296, ... -0.00331, -0.0636, 0.552, -0.391]
# Res_LPT= [-0.0712, 0.0137, -0.118, 0.219, 0.294, ... -0.0256, -0.0103, 0.00184, 0.538, -0.392]
# All good!
# Good!
# Lpt_pt= [[4.86, 4.15], [7.34, 4.87], [14.8, 6.89, ... 4.95], [4.12, 2.86], [6.21, 5.09]]
# len(Lpt_pt_flat)= 1074
# GED_pt= [[4.87, 4.15], [7.37, 4.86], [15.5, 6.84, ... 10.2, 5.17], [4.07, 2.87], [6.2, 5.17]]
# len(GED_pt_flat)= 1074
# Res_GED= [-0.00518, -0.0446, 0.0204, -0.0121, 0.0537, ... -0.00794, -0.0116, 0.209, -0.17]
# Res_LPT= [-0.00783, -0.0433, 0.0168, -0.00977, 0.00316, ... 0.00486, -0.0157, 0.211, -0.182]
# All good!
# Good!
# Lpt_pt= [[5.38, 2.51], [7.42, 5.87], [10, 3.73], ... 6.96, 4.44], [7.42, 4.69], [5.71, 3.88]]
# len(Lpt_pt_flat)= 4182
# GED_pt= [[5.19, 2.52], [6.37, 5.62], [10.1, 3.73, ... 4.42], [7.48, 4.65], [5.79, 3.91]]
# len(GED_pt_flat)= 4182
# Res_GED= [-0.0396, -0.031, 0.188, -0.0415, 0.0329, ... 3.56e-05, 0.0111, -0.017, 0.462, -0.34]
# Res_LPT= [-0.00452, -0.0335, 0.384, 0.0014, 0.0318, ... 0.00257, -0.00806, 0.442, -0.345]
# All good!
# Good!
# Lpt_pt= [[8.89, 8.51], [10.8, 3.38], [4.67, 3.26, ... 2.92], [7.32, 4.32], [12.2, 3.96]]
# len(Lpt_pt_flat)= 6816
# GED_pt= [[9, 8.58], [10.7, 3.45], [4.64, 3.01], ... [3.91, 2.93], [7.78, 3.92], [12, 4.14]]
# len(GED_pt_flat)= 6816
# Res_GED= [-0.00343, 0.000461, 0.0943, 0.134, 0.469, ... 0.0895, -0.223, -0.0265, -0.0489]
# Res_LPT= [-0.0154, -0.00777, 0.104, 0.111, 0.478, ... 0.0254, -0.146, -0.00695, -0.0891]
# All good!
# Good!
# Lpt_pt= [[14, 5.09], [6.22, 3.05], [9.72, 7.69], ... [17.4, 9.87], [15.3, 5.3], [11.5, 7.02]]
# len(Lpt_pt_flat)= 1362
# GED_pt= [[14.4, 5.15], [6.2, 3.04], [9.2, 7.59], ... [17.6, 9.9], [14.9, 5.41], [11.5, 6.96]]
# len(GED_pt_flat)= 1362
# Res_GED= [-0.0503, -0.239, 0.0145, -0.253, 0.244, ... -0.0291, 0.0322, 0.016, 0.000984]
# Res_LPT= [-0.0785, -0.247, 0.0173, -0.251, 0.314, ... -0.00167, 0.0122, 0.0164, 0.0105]
# All good!
# Good!
# Lpt_pt= [[14.5, 7.7], [7.55, 2.7], [14.3, 2.73], ... 8.96, 5.96], [26.1, 9.32], [7.09, 5.35]]
# len(Lpt_pt_flat)= 19002
# GED_pt= [[14.4, 6.82], [7.53, 2.7], [15.4, 2.85, ... 9.05, 5.97], [30.1, 9.66], [7.05, 5.44]]
# len(GED_pt_flat)= 19002
# Res_GED= [0.9, -0.529, 1.8, -0.651, -0.107, -0.538, ... -0.347, 1.69, -0.676, -0.112, -0.0569]
# Res_LPT= [0.905, -0.469, 1.8, -0.65, -0.168, ... -0.348, 1.34, -0.688, -0.108, -0.0724]
# All good!
# Good!
# Lpt_pt= [[7.96, 5.89], [7.36, 3.31], [7.63, 3.62, ... 2.03], [6.22, 6.09], [6.57, 4.35]]
# len(Lpt_pt_flat)= 3020
# GED_pt= [[8.04, 5.8], [7.42, 3.39], [7.73, 3.7], ... 6.31, 2.04], [6.11, 6.09], [6.58, 5.73]]
# len(GED_pt_flat)= 3020
# Res_GED= [-0.00281, 0.0213, -0.0707, 0.0455, 1.13, ... 0.0592, 0.0108, 0.00847, -0.0261]
# Res_LPT= [-0.0131, 0.0366, -0.0773, 0.0222, 1.1, ... -0.305, 0.0782, 0.01, 0.00629, -0.261]
# All good!
# Good!
# Lpt_pt= [[8.91, 7.28], [8.35, 3.18], [7.62, 2.74, ... 5.85], [5.63, 4.98], [7.16, 2.83]]
# len(Lpt_pt_flat)= 1330
# GED_pt= [[8.87, 7.32], [8.17, 3.21], [7.83, 2.86], ... [12.5, 7.22], [5.8, 5], [7.24, 3.18]]
# len(GED_pt_flat)= 1330
# Res_GED= [0.191, -0.184, -0.0497, -0.146, 1.81, ... -0.0281, 0.124, -0.155, 1.58, -0.562]
# Res_LPT= [0.197, -0.188, -0.0285, -0.155, 1.74, ... -0.212, 0.0893, -0.16, 1.55, -0.61]
# All good!
# Good!
# Lpt_pt= [[12.5, 6.51], [4.66, 2.39], [5.92, 4.33, ... 4.98], [21.9, 5.62], [18.9, 9.06]]
# len(Lpt_pt_flat)= 15514
# GED_pt= [[15.3, 6.26], [4.67, 2.53], [6.03, 4.31, ... 9.02], [21.4, 5.92], [19.2, 8.94]]
# len(GED_pt_flat)= 15514
# Res_GED= [1.34, -0.59, -0.00215, 0.0729, 0.0268, ... -0.0793, 2.58, -0.745, 1.33, -0.53]
# Res_LPT= [0.917, -0.574, -0.00366, 0.0155, 0.00757, ... -0.492, 2.66, -0.758, 1.29, -0.524]
# All good!
# Good!
# Lpt_pt= [[7.09, 2.73], [9.52, 4.95], [4.21, 2.46, ... 10.3], [4.96, 4.73], [6.21, 5.91]]
# len(Lpt_pt_flat)= 726
# GED_pt= [[7.16, 2.73], [9.56, 7.3], [4.25, 2.52], ... [11.1, 10.3], [5.1, 3.8], [6.22, 5.93]]
# len(GED_pt_flat)= 726
# Res_GED= [1.56, -0.681, 0.118, -0.246, 0.786, ... -0.000258, -0.0194, 0.0459, -0.0673]
# Res_LPT= [1.53, -0.681, 0.114, -0.489, 0.771, ... -0.0266, -0.027, 0.222, 0.0427, -0.0707]
# All good!
# Good!
# Lpt_pt= [[14.5, 3.25], [15.5, 9.5], [8.07, 3.74], ... 13.3, 2.29], [16.8, 4.46], [7.2, 6.93]]
# len(Lpt_pt_flat)= 11152
# GED_pt= [[15.1, 3.66], [15.3, 11.7], [8.07, 3.98, ... 2.35], [18.1, 4.14], [8.85, 7.79]]
# len(GED_pt_flat)= 11152
# Res_GED= [3.82, -0.733, 0.198, -0.297, 0.00872, ... -0.841, 0.042, -0.0803, 0.191, -0.236]
# Res_LPT= [3.63, -0.763, 0.213, -0.427, 0.00833, ... -0.846, -0.0336, -0.0104, -0.031, -0.32]
# All good!
# Good!
# Lpt_pt= [[21, 8.62], [4.71, 4.11], [2.87, 2.22], ... 5.03, 2.31], [2.36, 2.36], [6.68, 2.71]]
# len(Lpt_pt_flat)= 1300
# GED_pt= [[21.1, 8.67], [5, 4.06], [2.86, 2.24], ... [5.04, 1.63], [2.39, 2.36], [6.68, 2.73]]
# len(GED_pt_flat)= 1300
# Res_GED= [0.0572, 0.0213, 0.104, -0.00798, 0.255, ... -0.674, -0.0255, -0.00876, 1.11, -0.603]
# Res_LPT= [0.0514, 0.0161, 0.0389, 0.00421, 0.256, ... -0.539, -0.0372, -0.0104, 1.11, -0.607]
# All good!
# Good!
# Lpt_pt= [[7.72, 2.47], [7.75, 7.16], [7.79, 6.61, ... 6.25], [6.41, 4.14], [6.05, 2.91]]
# len(Lpt_pt_flat)= 4088
# GED_pt= [[7.98, 2.53], [7.7, 3.97], [7.85, 6.64], ... 6.8, 6.64], [6.45, 4.16], [5.85, 2.91]]
# len(GED_pt_flat)= 4088
# Res_GED= [2.2, -0.67, 1, -0.517, 0.159, -0.171, ... -0.0272, 0.0141, -0.136, 0.151, 0.014]
# Res_LPT= [2.1, -0.678, 1.02, -0.128, 0.151, -0.175, ... -0.0842, 0.00828, -0.14, 0.19, 0.012]
# All good!
# Good!
# Lpt_pt= [[5.19, 2.71], [5.81, 3.25], [14, 5.4], ... [6.65, 3.63], [15.5, 13.7], [8.93, 7.25]]
# len(Lpt_pt_flat)= 690
# GED_pt= [[5.2, 2.72], [5.83, 3.29], [15.3, 5.59], ... [6.66, 3.67], [16.9, 15], [9.33, 9.18]]
# len(GED_pt_flat)= 690
# Res_GED= [0.938, -0.556, 0.011, -0.0411, 1.7, ... 0.0302, 0.158, -0.118, 0.0371, 0.0434]
# Res_LPT= [0.933, -0.557, 0.00729, -0.0507, 1.46, ... 0.0174, 0.0658, -0.196, -0.00758, -0.176]
# All good!
# Good!
# Lpt_pt= [[5.25, 4.99], [8.05, 4.92], [9.19, 4.43, ... 6.31], [10.2, 2.71], [8.25, 4.64]]
# len(Lpt_pt_flat)= 6576
# GED_pt= [[5.25, 4.96], [8.21, 4.98], [9.27, 4.44], ... 10.6, 6.4], [9.6, 2.74], [8.21, 4.76]]
# len(GED_pt_flat)= 6576
# Res_GED= [-0.0575, 0.00956, 0.44, -0.423, -0.0298, ... 0.113, 0.0844, 0.00702, 0.733, -0.417]
# Res_LPT= [-0.0573, 0.0172, 0.412, -0.431, -0.0379, ... 0.0961, 0.151, -0.00681, 0.743, -0.432]
# All good!
# Good!
# Lpt_pt= [[15.6, 6.12], [9.35, 6.37], [5.5, 4.35, ... 3.82, 3.07], [5.83, 4.29], [10.2, 5.23]]
# len(Lpt_pt_flat)= 1974
# GED_pt= [[15.9, 6.15], [10.1, 6.83], [5.68, 4.42, ... 3.07], [5.86, 4.31], [10.1, 4.77]]
# len(GED_pt_flat)= 1974
# Res_GED= [1.63, -0.616, 0.654, -0.318, 0.01, -0.0278, ... -0.181, 0.197, -0.336, 1.2, -0.523]
# Res_LPT= [1.58, -0.618, 0.524, -0.363, -0.0232, ... -0.183, 0.191, -0.34, 1.23, -0.477]
# All good!
# Good!
# Lpt_pt= [[7.05, 5.13], [9.69, 2.37], [5.19, 4.57, ... 10.4, 3.28], [9.03, 8.41], [5.9, 4.32]]
# len(Lpt_pt_flat)= 148
# GED_pt= [[6.95, 5.35], [9.7, 2.87], [5.2, 4.63], ... 10.3, 3.37], [8.41, 4.98], [5.44, 5.31]]
# len(GED_pt_flat)= 148
# Res_GED= [-0.122, -0.136, 3.25, -0.703, -0.00626, ... -0.337, -0.384, -0.0792, -0.023]
# Res_LPT= [-0.109, -0.172, 3.25, -0.755, -0.00769, ... -0.288, 0.041, -0.00184, -0.205]
# All good!
# Good!
# Lpt_pt= [[3.02, 2.27], [4.31, 3.09], [6.92, 6.77, ... 7.54, 5.36], [4.81, 3.07], [5.7, 4.21]]
# len(Lpt_pt_flat)= 166
# GED_pt= [[3.02, 2.31], [4.32, 3.07], [6.27, 2.61, ... 5.72], [4.81, 3.08], [6.69, 4.04]]
# len(GED_pt_flat)= 166
# Res_GED= [0.298, -0.226, -0.00229, -0.0341, -0.0467, ... -0.373, 0.59, -0.363, -0.232, -0.147]
# Res_LPT= [0.299, -0.239, -0.00364, -0.0298, 0.052, ... -0.412, 0.589, -0.364, -0.345, -0.111]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
