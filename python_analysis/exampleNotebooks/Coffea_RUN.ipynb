# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/analysisTools/")
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os
from analysisTools import loadSchema
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

print("has singletons?", hasattr(ak, "singletons"))
print("awkward module path:", getattr(ak, "__file__", "<built-in>"))
print(ak.__version__)
# Out:
# has singletons? True
# awkward module path: /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/__init__.py
# 1.10.3

# %%
# sample_config = "../configs/sample_configs/signal_2022_Mchi-77p0_dMchi-14p0_ctau-1_100_aEM.json"
# sample_config = "../configs/sample_configs/signal_2022_Mchi-22p0_dMchi-4p0_ctau-1_100_aEM.json"
# sample_config = "../configs/sample_configs/signal_2022_Mchi-44p0_dMchi-8p0_ctau-1_100_aEM.json"

# sample_config = "../configs/sample_configs/signal_2022_Mchi_10_30_50_ctau10mm_AllInOne_aEM.json"
sample_config = "../configs/sample_configs/signal_2022_Run3_sigfiles_2022_aEM.json"

cuts_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/cut_configs/cuts.py" 

histos_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/histo_configs/histos_AllInOne.py"  
# model_config = "../configs/models/BDT_NJetG0_allSigns_goodvtx_v11_max_depth_7_n_estimators_800_lr_0.005.json"

# %%
outdir = "../coffea/AllInOne_2022/"
# outdir = "../coffea/SampleFactoryProducts_2022/"

os.makedirs(outdir, exist_ok=True)

# %%
analyzer = Analyzer(sample_config, histos_config, cuts_config,max_files_per_samp=1) 

t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

util.save(out,f"{outdir}/Resolution.coffea")
# util.save(out,f"{outdir}/Sig77_14_ctau1_100.coffea")

# util.save(out,f"{outdir}/Sig77_14_ctau1_100.coffea")
# Out:
# Running with systematics:  None
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# All good!
# Good!
# GenEle_pt= [5.77, 5.1, 5.48, 5.45, 5.26, 5.35, 5.65, 5.24]
# 8
# GenPos_pt= [5.54, 5.93, 5.24, 5.49, 5.99, 5.81, 5.71, 5.09]
# 8
# Gen_pt= [[5.77, 5.54], [5.1, 5.93], [5.48, 5.24, ... 5.35, 5.81], [5.65, 5.71], [5.24, 5.09]]
# len(Gen_pt_FLAT)= 16
# Lpt_pt= [[5.59, 5.48], [5.94, 5.17], [5.42, 4.87, ... 3.86], [5.71, 4.47], [5.14, 4.91]]
# len(Lpt_pt_flat)= 16
# GED_pt= [[5.57, 5.51], [5.97, 5.19], [5.75, 5.19, ... 5.58, 3.86], [5.68, 4.89], [6.35, 5.1]]
# len(GED_pt_flat)= 16
# Res_GED= [-0.0341, -0.00448, 0.169, -0.125, 0.0502, ... 0.0052, -0.142, 0.211, 0.00141]
# Res_LPT= [-0.0306, -0.0108, 0.164, -0.127, -0.0104, ... 0.00968, -0.217, -0.0185, -0.0367]
# All good!
# Good!
# GenEle_pt= [5.67, 5.96, 5.49, 5.62, 5.47, 5.13, 5.08, ... 5.13, 5.91, 5.63, 5.46, 5.69, 5.41]
# 81
# GenPos_pt= [5.7, 5.97, 5.42, 5.55, 5.46, 5.27, 6, ... 5.34, 5.24, 5.77, 5.32, 5.8, 5.24, 5.47]
# 81
# Gen_pt= [[5.67, 5.7], [5.96, 5.97], [5.49, 5.42], ... 5.46, 5.8], [5.69, 5.24], [5.41, 5.47]]
# len(Gen_pt_FLAT)= 162
# Lpt_pt= [[5.55, 4.71], [6.01, 5.45], [5.61, 5.53, ... 5.66, 5.53], [5.6, 5.24], [5.47, 5.35]]
# len(Lpt_pt_flat)= 162
# GED_pt= [[5.56, 4.82], [6.1, 3.99], [5.61, 5.53], ... 5.64, 5.51], [5.92, 5.3], [5.48, 5.34]]
# len(GED_pt_flat)= 162
# Res_GED= [-0.019, -0.154, 0.0245, -0.332, 0.0226, ... 0.0401, 0.0121, 0.0142, -0.0231]
# Res_LPT= [-0.0214, -0.174, 0.00959, -0.0871, 0.0218, ... -0.0148, 0.000457, 0.0117, -0.0211]
# All good!
# Good!
# GenEle_pt= []
# 0
# GenPos_pt= []
# 0
# Gen_pt= []
# len(Gen_pt_FLAT)= 0
# Lpt_pt= []
# len(Lpt_pt_flat)= 0
# GED_pt= []
# len(GED_pt_flat)= 0
# Res_GED= []
# Res_LPT= []
# All good!
# Good!
# GenEle_pt= [5, 5.1, 5.86, 5.77, 5.88, 5.25, 5.52, ... 5.5, 5.11, 5.07, 5.9, 5.05, 5.84, 5.28]
# 88
# GenPos_pt= [5.11, 5.87, 5.02, 5.72, 5.23, 5.51, 5.91, ... 5.77, 5.6, 5.37, 5.31, 5.17, 5.34]
# 88
# Gen_pt= [[5, 5.11], [5.1, 5.87], [5.86, 5.02], ... [5.05, 5.31], [5.84, 5.17], [5.28, 5.34]]
# len(Gen_pt_FLAT)= 176
# Lpt_pt= [[5.16, 5.13], [5.91, 4.81], [5.48, 4.88, ... 5.41, 4.9], [5.92, 5.14], [5.34, 5.33]]
# len(Lpt_pt_flat)= 176
# GED_pt= [[5.14, 5.14], [5.91, 4.94], [5.52, 4.92, ... 4.91], [5.91, 5.13], [5.37, 5.33]]
# len(GED_pt_flat)= 176
# Res_GED= [0.0278, 0.00433, 0.159, -0.158, -0.0575, ... 0.0123, -0.00744, 0.0164, -0.00152]
# Res_LPT= [0.0306, 0.00254, 0.161, -0.18, -0.0645, ... 0.0132, -0.007, 0.0107, -0.00218]
# All good!
# Good!
# GenEle_pt= [5.69, 5.65, 5.62, 5.52, 5.56, 5.68, 5.41, ... 5.92, 5.86, 5.86, 5.38, 5.21, 5.24]
# 14
# GenPos_pt= [5.83, 5.97, 5.67, 5.16, 5.89, 5.39, 5.97, ... 5.22, 5.08, 5.74, 5.99, 5.88, 5.68]
# 14
# Gen_pt= [[5.69, 5.83], [5.65, 5.97], [5.62, 5.67, ... 5.99], [5.21, 5.88], [5.24, 5.68]]
# len(Gen_pt_FLAT)= 28
# Lpt_pt= [[6.08, 5.61], [7.33, 6.26], [5.42, 5.05, ... 5.93, 5.36], [5.74, 5.38], [5.51, 5.4]]
# len(Lpt_pt_flat)= 28
# GED_pt= [[6.09, 5.79], [6.52, 6.26], [5.46, 4.86, ... 5.33], [5.77, 5.35], [5.52, 5.37]]
# len(GED_pt_flat)= 28
# Res_GED= [0.0705, -0.00706, 0.154, 0.048, -0.0274, ... -0.11, 0.108, -0.0901, 0.0535, -0.0544]
# Res_LPT= [0.0699, -0.0374, 0.297, 0.048, -0.035, ... -0.106, 0.102, -0.0843, 0.0514, -0.0503]
# All good!
# Good!
# GenEle_pt= [5.94, 5.86, 5.46]
# 3
# GenPos_pt= [5.18, 5.37, 5.68]
# 3
# Gen_pt= [[5.94, 5.18], [5.86, 5.37], [5.46, 5.68]]
# len(Gen_pt_FLAT)= 6
# Lpt_pt= [[5.08, 5.03], [5.27, 5.24], [5.66, 5.51]]
# len(Lpt_pt_flat)= 6
# GED_pt= [[6.41, 5.12], [5.33, 5.24], [5.61, 5.51]]
# len(GED_pt_flat)= 6
# Res_GED= [0.0778, -0.0121, -0.0907, -0.0252, 0.0283, -0.0287]
# Res_LPT= [-0.145, -0.0282, -0.0999, -0.0235, 0.0373, -0.0301]
# All good!
# Good!
# GenEle_pt= [5.38, 5.2, 5.85, 5.75, 5.29, 5.01, 5.76, ... 5.54, 5.42, 5.31, 5.39, 5.05, 5.86]
# 115
# GenPos_pt= [5.45, 5.16, 5.78, 5.31, 5.77, 5.6, 5.33, ... 5.68, 5.95, 5.88, 5.17, 5.39, 5.64]
# 115
# Gen_pt= [[5.38, 5.45], [5.2, 5.16], [5.85, 5.78, ... 5.39, 5.17], [5.05, 5.39], [5.86, 5.64]]
# len(Gen_pt_FLAT)= 230
# Lpt_pt= [[5.31, 5.09], [5.41, 5.21], [5.68, 5.59, ... 6.11], [5.53, 4.67], [6.08, 4.16]]
# len(Lpt_pt_flat)= 230
# GED_pt= [[5.12, 5.07], [5.46, 5.2], [5.75, 5.65, ... 7.61, 5.57], [5.53, 4.69], [6.44, 5.33]]
# len(GED_pt_flat)= 230
# Res_GED= [-0.0489, -0.0701, 0.0501, 0.00731, -0.017, ... 0.095, -0.129, 0.099, -0.0557]
# Res_LPT= [-0.0121, -0.0657, 0.0409, 0.00959, -0.0292, ... 0.0952, -0.133, 0.0367, -0.263]
# All good!
# Good!
# GenEle_pt= [5.9, 5.41, 5.16, 5.15, 5.24, 5.18, 5.88, ... 5.62, 5.02, 5.85, 5.67, 5.17, 5.77]
# 17
# GenPos_pt= [5.58, 5.67, 5.55, 5.58, 5.46, 5.61, 5.76, ... 5.43, 5.85, 5.68, 5.91, 5.79, 5.08]
# 17
# Gen_pt= [[5.9, 5.58], [5.41, 5.67], [5.16, 5.55, ... 5.67, 5.91], [5.17, 5.79], [5.77, 5.08]]
# len(Gen_pt_FLAT)= 34
# Lpt_pt= [[5.66, 5.41], [5.6, 5.43], [5.4, 5.18], ... [5.75, 5.3], [5.8, 5.66], [4.93, 2.93]]
# len(Lpt_pt_flat)= 34
# GED_pt= [[5.88, 5.43], [5.6, 5.42], [5.39, 5.14], ... [6.09, 5.36], [5.8, 4.61], [4.9, 4.89]]
# len(GED_pt_flat)= 34
# Res_GED= [-0.00323, -0.0266, 0.0357, -0.0444, 0.0455, ... 0.12, -0.204, -0.152, -0.037]
# Res_LPT= [-0.0396, -0.0307, 0.0363, -0.0435, 0.0465, ... 0.121, -0.0233, -0.147, -0.423]
# All good!
# Good!
# GenEle_pt= [5.06, 5.51, 5.67, 5.18, 5.67, 5.81, 5.84, ... 5.7, 5.4, 5.81, 5.22, 5.27, 5.81]
# 93
# GenPos_pt= [5.16, 5.5, 5.23, 5.77, 5.5, 5.7, 5.41, ... 5.73, 5.71, 5.18, 5.55, 5.92, 5.53, 5.72]
# 93
# Gen_pt= [[5.06, 5.16], [5.51, 5.5], [5.67, 5.23, ... 5.22, 5.92], [5.27, 5.53], [5.81, 5.72]]
# len(Gen_pt_FLAT)= 186
# Lpt_pt= [[5.22, 5], [5.54, 5.53], [5.36, 5.07], ... [5.86, 5.2], [5.28, 4.99], [5.82, 4.57]]
# len(Lpt_pt_flat)= 186
# GED_pt= [[5.45, 5.25], [5.76, 5.52], [5.32, 5.1, ... 5.83, 5.17], [5.26, 5.01], [5.83, 4.64]]
# len(GED_pt_flat)= 186
# Res_GED= [0.0765, 0.016, 0.046, 0.00316, -0.0621, ... -0.00076, -0.0951, 0.00315, -0.189]
# Res_LPT= [0.0316, -0.0323, 0.00598, 0.005, -0.0553, ... 0.00235, -0.0979, 0.00129, -0.201]
# All good!
# Good!
# GenEle_pt= [5.61, 5.69, 5.25, 5.75, 5.63, 5.81, 5.07]
# 7
# GenPos_pt= [5.01, 5.03, 5.44, 5.8, 5.17, 5.75, 5.59]
# 7
# Gen_pt= [[5.61, 5.01], [5.69, 5.03], [5.25, 5.44, ... 5.17], [5.81, 5.75], [5.07, 5.59]]
# len(Gen_pt_FLAT)= 14
# Lpt_pt= [[5.67, 5.07], [5.55, 4.63], [5.3, 5], ... [5.92, 5.06], [5.73, 5.67], [5.66, 5.1]]
# len(Lpt_pt_flat)= 14
# GED_pt= [[5.8, 5.1], [5.61, 4.63], [5.3, 4.99], ... [6, 5.89], [5.79, 5.64], [5.64, 5.11]]
# len(GED_pt_flat)= 14
# Res_GED= [0.0339, 0.0168, -0.0139, -0.0781, 0.00966, ... -0.00303, -0.02, 0.112, -0.0861]
# Res_LPT= [0.00944, 0.0118, -0.0251, -0.0787, 0.0107, ... -0.0133, -0.0141, 0.116, -0.0874]
# All good!
# Good!
# GenEle_pt= [5.64, 5.41, 5.01, 5.87, 5.41, 5.88, 5.56, ... 5.18, 5.91, 5.65, 5.36, 5.27, 5.31]
# 33
# GenPos_pt= [5.75, 5.06, 5.38, 5.86, 5.49, 5.25, 5.66, ... 5.32, 5.18, 5.54, 5.05, 5.54, 5.52]
# 33
# Gen_pt= [[5.64, 5.75], [5.41, 5.06], [5.01, 5.38, ... 5.05], [5.27, 5.54], [5.31, 5.52]]
# len(Gen_pt_FLAT)= 66
# Lpt_pt= [[5.72, 5.56], [5.04, 4.06], [5.41, 4.95, ... 5.03], [5.33, 5.18], [5.18, 4.93]]
# len(Lpt_pt_flat)= 66
# GED_pt= [[5.72, 5.52], [5.02, 4.09], [5.43, 4.91, ... 5.08], [5.35, 5.15], [5.27, 4.97]]
# len(GED_pt_flat)= 66
# Res_GED= [0.0156, -0.0389, -0.0718, -0.192, 0.0835, ... 0.0152, -0.0705, -0.00694, -0.0999]
# Res_LPT= [0.0152, -0.033, -0.0682, -0.198, 0.0785, ... 0.0113, -0.0643, -0.0242, -0.107]
# All good!
# Good!
# GenEle_pt= [5.65, 5.16, 5.14, 5.49, 5.56, 5.46, 6, 5.76, 5.99, 5.17]
# 10
# GenPos_pt= [5.9, 5.14, 5.65, 5.32, 5.74, 5.56, 5.72, 5.06, 5.6, 5.92]
# 10
# Gen_pt= [[5.65, 5.9], [5.16, 5.14], [5.14, 5.65], ... 5.76, 5.06], [5.99, 5.6], [5.17, 5.92]]
# len(Gen_pt_FLAT)= 20
# Lpt_pt= [[5.98, 5.88], [5.01, 5.01], [5.27, 4], ... [5.61, 5.57], [5.91, 4.59], [5.63, 4.98]]
# len(Lpt_pt_flat)= 20
# GED_pt= [[6, 5.9], [5.12, 5.02], [5.57, 5], ... [5.74, 5.61], [6.04, 5.16], [5.8, 5]]
# len(GED_pt_flat)= 20
# Res_GED= [0.0616, 0.000697, -0.00661, -0.0221, 0.0841, ... 0.00837, -0.0791, 0.124, -0.155]
# Res_LPT= [0.0591, -0.00384, -0.0279, -0.0243, 0.0248, ... -0.0144, -0.18, 0.0893, -0.16]
# All good!
# Good!
# GenEle_pt= [5.15, 5.96, 5.48, 5.05, 5.66, 5.65, 5.33, ... 5.13, 5.47, 5.69, 5.89, 5.01, 5.2]
# 85
# GenPos_pt= [5.35, 5.31, 5.07, 5.04, 5.94, 5.71, 5.6, ... 5.21, 5.61, 5.18, 5.09, 5.84, 5.05]
# 85
# Gen_pt= [[5.15, 5.35], [5.96, 5.31], [5.48, 5.07, ... 5.89, 5.09], [5.01, 5.84], [5.2, 5.05]]
# len(Gen_pt_FLAT)= 170
# Lpt_pt= [[5.39, 5.36], [6.03, 5.32], [5.41, 4.95, ... 5.72, 5.01], [7.57, 4.77], [5.14, 5.1]]
# len(Lpt_pt_flat)= 170
# GED_pt= [[5.6, 5.35], [6.06, 5.36], [5.39, 4.96, ... 5.73, 5.04], [9.31, 5.14], [5.19, 5.09]]
# len(GED_pt_flat)= 170
# Res_GED= [0.0874, -0.000485, 0.0166, 0.0088, -0.0162, ... 0.859, -0.119, -0.0018, 0.00794]
# Res_LPT= [0.047, 0.00166, 0.0108, 0.00226, -0.013, ... 0.51, -0.183, -0.0117, 0.00981]
# All good!
# Good!
# GenEle_pt= [5.9, 5.45, 5.86, 5.48, 5.47, 5.44, 5.62, ... 5.59, 5.32, 5.89, 5.31, 5.65, 5.71]
# 73
# GenPos_pt= [5.89, 5.27, 5.16, 5.09, 5.52, 5.46, 5.63, ... 5.79, 5.2, 5.04, 5.68, 5.08, 5.37]
# 73
# Gen_pt= [[5.9, 5.89], [5.45, 5.27], [5.86, 5.16, ... 5.31, 5.68], [5.65, 5.08], [5.71, 5.37]]
# len(Gen_pt_FLAT)= 146
# Lpt_pt= [[5.75, 5.12], [5.23, 5.19], [5.77, 5.06, ... 5.37], [6.19, 5.03], [5.67, 5.44]]
# len(Lpt_pt_flat)= 146
# GED_pt= [[5.73, 5.18], [5.22, 5.21], [5.78, 5.07, ... 5.38], [5.65, 5.06], [5.66, 5.47]]
# len(GED_pt_flat)= 146
# Res_GED= [-0.0274, -0.121, -0.043, -0.0112, -0.0131, ... -0.000707, -0.0042, -0.0101, 0.0187]
# Res_LPT= [-0.0254, -0.131, -0.0405, -0.0152, -0.0157, ... 0.0951, -0.00939, -0.00669, 0.0128]
# All good!
# Good!
# GenEle_pt= [5.53, 5.22, 5.47, 5.8, 5.32, 5.2, 5.37, 5.39, 5.94]
# 9
# GenPos_pt= [5.33, 5.69, 5.34, 5.8, 5.86, 5.55, 5.68, 5.63, 5.14]
# 9
# Gen_pt= [[5.53, 5.33], [5.22, 5.69], [5.47, 5.34, ... 5.68], [5.39, 5.63], [5.94, 5.14]]
# len(Gen_pt_FLAT)= 18
# Lpt_pt= [[4.24, 3.48], [5.62, 5.08], [5.39, 5.34], ... 5.82, 3.51], [5.7, 5.37], [5.95, 5.8]]
# len(Lpt_pt_flat)= 18
# GED_pt= [[4.35, 3.53], [5.62, 5.14], [5.4, 5.36, ... 5.79, 3.61], [5.64, 5.37], [5.92, 5.89]]
# len(GED_pt_flat)= 18
# Res_GED= [-0.213, -0.339, 0.076, -0.0969, -0.0117, ... 0.0451, -0.0467, -0.00315, 0.147]
# Res_LPT= [-0.233, -0.347, 0.0756, -0.107, -0.0137, ... -0.382, 0.0575, -0.0471, 0.00215, 0.13]
# All good!
# Good!
# GenEle_pt= [5.02, 5.16, 5.65, 5.91, 5.87, 5.05, 5.5, ... 5.76, 5.82, 5.47, 5.71, 5.4, 5.86]
# 15
# GenPos_pt= [5.64, 5.6, 5.19, 5.16, 5.88, 5.54, 5.54, ... 5.75, 5.46, 5.78, 5.56, 5.29, 5.98]
# 15
# Gen_pt= [[5.02, 5.64], [5.16, 5.6], [5.65, 5.19], ... 5.71, 5.56], [5.4, 5.29], [5.86, 5.98]]
# len(Gen_pt_FLAT)= 30
# Lpt_pt= [[5.96, 4.07], [4.93, 4.32], [5.02, 4.87, ... 5.63], [5.35, 5.21], [5.92, 5.69]]
# len(Lpt_pt_flat)= 30
# GED_pt= [[6.05, 4.24], [4.95, 4.33], [5.62, 4.95, ... 5.64], [5.37, 4.75], [5.91, 5.73]]
# len(GED_pt_flat)= 30
# Res_GED= [0.204, -0.248, -0.0414, -0.226, -0.00481, ... -0.00391, -0.102, 0.00814, -0.0426]
# Res_LPT= [0.187, -0.279, -0.0445, -0.228, -0.112, ... -0.00862, -0.0143, 0.0108, -0.0484]
# All good!
# Good!
# GenEle_pt= [5.18, 5.51, 5.99, 5.02, 5.5, 5.91, 5.12, ... 5.37, 5.78, 5.25, 5.83, 5.36, 5.19]
# 42
# GenPos_pt= [5.77, 5.52, 5.24, 5.43, 5.42, 5.92, 5.69, ... 5.39, 5.69, 5.58, 5.87, 5.06, 5.41]
# 42
# Gen_pt= [[5.18, 5.77], [5.51, 5.52], [5.99, 5.24, ... 5.87], [5.36, 5.06], [5.19, 5.41]]
# len(Gen_pt_FLAT)= 84
# Lpt_pt= [[5.54, 5.2], [5.4, 5.36], [5.68, 5.15], ... [9.99, 5.78], [5.35, 5], [5.47, 5.44]]
# len(Lpt_pt_flat)= 84
# GED_pt= [[5.53, 5.2], [5.5, 5.36], [5.64, 5.17], ... 5.81, 5.77], [5.37, 5.05], [5.49, 5.36]]
# len(GED_pt_flat)= 84
# Res_GED= [0.0666, -0.0979, -0.00168, -0.0294, -0.057, ... 0.00299, -0.00308, 0.0577, -0.00784]
# Res_LPT= [0.0677, -0.0978, -0.0188, -0.0289, -0.0513, ... -0.000921, -0.0122, 0.0538, 0.00555]
# All good!
# Good!
# GenEle_pt= [5.63, 5.49, 5.97, 5.21, 5.6, 5.61, 5.65]
# 7
# GenPos_pt= [5.27, 5.68, 5.9, 5.91, 5.31, 5.66, 5.62]
# 7
# Gen_pt= [[5.63, 5.27], [5.49, 5.68], [5.97, 5.9], ... 5.6, 5.31], [5.61, 5.66], [5.65, 5.62]]
# len(Gen_pt_FLAT)= 14
# Lpt_pt= [[5.51, 5.23], [5.44, 4.49], [5.91, 5.71, ... 5.25, 4.67], [5.53, 5.45], [5.6, 3.91]]
# len(Lpt_pt_flat)= 14
# GED_pt= [[5.92, 5.25], [5.46, 5.45], [5.92, 5.73, ... 4.67], [5.54, 5.48], [5.04, 4.21]]
# len(GED_pt_flat)= 14
# Res_GED= [0.0515, -0.00481, -0.00519, -0.0411, -0.00799, ... -0.0112, -0.0308, -0.109, -0.25]
# Res_LPT= [-0.0215, -0.00765, -0.00962, -0.209, ... -0.0132, -0.0359, -0.00972, -0.304]
# All good!
# Good!
# GenEle_pt= [5.2, 5.48, 5.81, 5.83, 5.78, 5.33, 5.52, ... 5.32, 5.86, 5.46, 5.71, 5.22, 5.37]
# 17
# GenPos_pt= [5.35, 5.43, 5.5, 5.28, 5.53, 5.73, 5.68, ... 5.87, 5.71, 5.06, 5.06, 5.13, 5.13]
# 17
# Gen_pt= [[5.2, 5.35], [5.48, 5.43], [5.81, 5.5], ... 5.71, 5.06], [5.22, 5.13], [5.37, 5.13]]
# len(Gen_pt_FLAT)= 34
# Lpt_pt= [[5.18, 5.17], [5.47, 5.07], [5.73, 5.44, ... 5.63, 5.05], [5.9, 3.95], [5.49, 5.31]]
# len(Lpt_pt_flat)= 34
# GED_pt= [[5.24, 5.21], [5.74, 5.2], [5.74, 5.45], ... [5.7, 5.07], [5.69, 3.83], [5.5, 5.47]]
# len(GED_pt_flat)= 34
# Res_GED= [0.00808, -0.0265, 0.048, -0.0425, -0.0124, ... 0.0905, -0.255, 0.0248, 0.0659]
# Res_LPT= [-0.00396, -0.0325, -0.00165, -0.0662, -0.0144, ... 0.131, -0.231, 0.022, 0.0344]
# All good!
# Good!
# GenEle_pt= [5.88, 5.35, 5.59, 5.2, 5.24, 5.91]
# 6
# GenPos_pt= [5.08, 5.53, 5.86, 5.8, 5.43, 5.44]
# 6
# Gen_pt= [[5.88, 5.08], [5.35, 5.53], [5.59, 5.86], ... 5.2, 5.8], [5.24, 5.43], [5.91, 5.44]]
# len(Gen_pt_FLAT)= 12
# Lpt_pt= [[5.72, 5.48], [7.01, 5.35], [5.76, 5.7], ... 5.08, 4.95], [5.48, 5.23], [5.9, 4.32]]
# len(Lpt_pt_flat)= 12
# GED_pt= [[6.16, 5.37], [6.04, 5.45], [5.71, 5.7], ... 5.25, 5.05], [5.5, 5.22], [5.44, 5.31]]
# len(GED_pt_flat)= 12
# Res_GED= [0.0473, 0.0562, 0.129, -0.0147, 0.021, ... -0.129, 0.0497, -0.0398, -0.0792, -0.023]
# Res_LPT= [-0.0272, 0.0786, 0.31, -0.0332, 0.03, ... -0.147, 0.0456, -0.038, -0.00184, -0.205]
# All good!
# Good!
# GenEle_pt= [5.26]
# 1
# GenPos_pt= [5.09]
# 1
# Gen_pt= [[5.26, 5.09]]
# len(Gen_pt_FLAT)= 2
# Lpt_pt= [[5.08, 5.08]]
# len(Lpt_pt_flat)= 2
# GED_pt= [[5.11, 5.1]]
# len(GED_pt_flat)= 2
# Res_GED= [-0.0288, 0.00247]
# Res_LPT= [-0.033, -0.00209]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
