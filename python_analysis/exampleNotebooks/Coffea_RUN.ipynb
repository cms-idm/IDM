# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/analysisTools/")
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os
from analysisTools import loadSchema
from analysisTools import Analyzer
from analysisTools import iDMeProcessor
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

print("has singletons?", hasattr(ak, "singletons"))
print("awkward module path:", getattr(ak, "__file__", "<built-in>"))
# Out:
# has singletons? True
# awkward module path: /uscms/home/reshmar/nobackup/miniforge3/envs/coffea/lib/python3.8/site-packages/awkward/__init__.py

# %%
sample_config = "../configs/sample_configs/signal_2022_Mchi_10_30_50_ctau10mm_AllInOne_aEM.json"
cuts_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/cut_configs/cuts.py" 

histos_config = "/uscms/home/reshmar/nobackup/IDMe_Run3_Collab/CMSSW_13_0_13/src/iDMe/python_analysis/thesis_plots/electron_xclean/histo_configs/histos_AllInOne.py"  
# model_config = "../configs/models/BDT_NJetG0_allSigns_goodvtx_v11_max_depth_7_n_estimators_800_lr_0.005.json"

# %%
outdir = "../coffea/AllInOne_2022/"
os.makedirs(outdir, exist_ok=True)

# %%
analyzer = Analyzer(sample_config, histos_config, cuts_config,max_files_per_samp=-1) 

t1 = time.time()
out = analyzer.process(execr="iterative")
#out = analyzer.process(execr='futures')
t2 = time.time()

#print("Runtime: {:.2f} minutes".format((t2-t1)/60))
util.save(out,f"{outdir}/AllInOne.coffea")
# Out:
# Running with systematics:  None
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# All good!
# Good!
# [<Array [1.6, 3.64, 3.59, ... 4.19, 5.94, 5.53] type='68996 * float32[parameters=...'>]
# total= [<Array [1.6, 3.64, 3.59, ... 4.19, 5.94, 5.53] type='68996 * float32[parameters=...'>, <Array [0.269, 5.52,
# 1.64, ... 1.01, 7.73] type='68996 * float32[parameters={"__...'>]
# [<Array [1.6, 3.64, 3.59, ... 4.19, 5.94, 5.53] type='68996 * float32[parameters=...'>, <Array [0.269, 5.52, 1.64,
# ... 1.01, 7.73] type='68996 * float32[parameters={"__...'>]
# All good!
# Good!
# [<Array [0.284, 7.24, 0.147, ... 5.9, 8.14] type='67153 * float32[parameters={"__...'>]
# total= [<Array [0.284, 7.24, 0.147, ... 5.9, 8.14] type='67153 * float32[parameters={"__...'>, <Array [6.11, 1.57,
# 2.32, ... 4.96, 3.77, 3.19] type='67153 * float32[parameters...'>]
# [<Array [0.284, 7.24, 0.147, ... 5.9, 8.14] type='67153 * float32[parameters={"__...'>, <Array [6.11, 1.57, 2.32,
# ... 4.96, 3.77, 3.19] type='67153 * float32[parameters...'>]
# All good!
# Good!
# [<Array [2.36, 1.33, 3.34, ... 8.49, 4.82, 1.5] type='64318 * float32[parameters=...'>]
# total= [<Array [2.36, 1.33, 3.34, ... 8.49, 4.82, 1.5] type='64318 * float32[parameters=...'>, <Array [1.25, 1.99,
# 0.29, ... 8.1, 2.71, 2.23] type='64318 * float32[parameters=...'>]
# [<Array [2.36, 1.33, 3.34, ... 8.49, 4.82, 1.5] type='64318 * float32[parameters=...'>, <Array [1.25, 1.99, 0.29,
# ... 8.1, 2.71, 2.23] type='64318 * float32[parameters=...'>]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
